# %% [markdown]
# ## Water extraction (Raster to vector)

# %%
import NDWI

# %%
NDWI.NDWI('T35TPF_20200822T084601_B03_10m.jp2', 'T35TPF_20200822T084601_B12_20m.jp2', 'result/2020agu_ndwi.tif')
NDWI.Calculate_Area('result/2020agu_ndwi.tif').print_screen()
NDWI.Vectorize('result/2020agu_ndwi.tif', '2020_agu.shp').show_vector()
# Out:
# NDWI has created succesfully
# 5667.59 km²

# %%
NDWI.NDWI('T35SMD_20200825T085601_B03_10m.jp2', 'T35SMD_20200825T085601_B12_20m.jp2', 'result/2020agu2_ndwi.tif')
NDWI.Calculate_Area('result/2020agu2_ndwi.tif').print_screen()
NDWI.Vectorize('result/2020agu2_ndwi.tif', '2020_agu2.shp').show_vector()
# Out:
# NDWI has created succesfully
# 6136.33 km²
