# %% [markdown]
# ## Ulubatlı Gölü

# %%
import NDWI

# %%
NDWI.NDWI('T35TPE_20200524T084601_B03_10m.jp2', 'T35TPE_20200524T084601_B12_20m.jp2', '2020mayndwi.tif')
NDWI.Clip_NDWI('2020mayndwi.tif', 'clipped_may.tif')
NDWI.Calculate_Area('clipped_may.tif').print_screen()
NDWI.Vectorize('clipped_may.tif', '2020_may.shp').show_vector()
# Out:
# NDWI has created succesfully
# 109.93 km²

# %%
NDWI.NDWI('T35TPE_20200812T084601_B03_10m.jp2', 'T35TPE_20200812T084601_B12_20m.jp2', '2020agundwi.tif')
NDWI.Clip_NDWI('2020agundwi.tif', 'clipped_agu.tif')
NDWI.Calculate_Area('clipped_agu.tif').print_screen()
NDWI.Vectorize('clipped_agu.tif', '2020_agu.shp').show_vector()
# Out:
# NDWI has created succesfully
# 105.23 km²
