# %% [markdown]
# ## Ulubatlı Gölü

# %%
import NDWI

# %%
NDWI.NDWI('T35TPE_20190530T084601_B03_10m.jp2', 'T35TPE_20190530T084601_B12_20m.jp2', 'mndvi_2019_may.tif')
NDWI.Calculate_Area('mndvi_2019_may.tif')
# Out:
# NDWI has created succesfully
# 111.81 km²

# %%
NDWI.NDWI('T35TPE_20200524T084601_B03_10m.jp2', 'T35TPE_20200524T084601_B12_20m.jp2', 'mndvi_2020_may.tif')
NDWI.Calculate_Area('mndvi_2020_may.tif')
# Out:
# NDWI has created succesfully
# 111.40 km²

# %%
NDWI.NDWI('T35TPE_20200812T084601_B03_10m.jp2', 'T35TPE_20200812T084601_B12_20m.jp2', 'mndvi_2020_agu.tif')
NDWI.Calculate_Area('mndvi_2020_agu.tif')
# Out:
# NDWI has created succesfully
# 110.07 km²
